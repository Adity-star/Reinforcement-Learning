# %% [markdown]
# # Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
# - Space Invaders using RL Baselines3 Zoo, a training framework based on Stable-Baselines3 that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.

# %% [markdown]
# ## 1. Environment

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /tmp/pip-req-build-y2xjvtv0
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-y2xjvtv0
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit 325ef5dafe46e483ce9d727d2851aff18b70db7c
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sb3_contrib<3.0,>=2.6.0 (from rl_zoo3==2.6.0)
#   Downloading sb3_contrib-2.6.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.6.0) (1.1.1)
# Collecting huggingface_sb3<4.0,>=3.0 (from rl_zoo3==2.6.0)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.6.0) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.6.0) (13.9.4)
# Collecting optuna>=3.0 (from rl_zoo3==2.6.0)
#   Downloading optuna-4.2.1-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.6.0) (6.0.2)
# Collecting pytablewriter~=1.2 (from rl_zoo3==2.6.0)
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# Collecting shimmy~=2.0 (from rl_zoo3==2.6.0)
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->rl_zoo3==2.6.0) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->rl_zoo3==2.6.0) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->rl_zoo3==2.6.0) (4.13.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->rl_zoo3==2.6.0) (0.0.4)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.11/dist-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (0.29.3)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.11/dist-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (1.1.3)
# Collecting alembic>=1.5.0 (from optuna>=3.0->rl_zoo3==2.6.0)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna>=3.0->rl_zoo3==2.6.0)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna>=3.0->rl_zoo3==2.6.0) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna>=3.0->rl_zoo3==2.6.0) (2.0.40)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.11/dist-packages (from pytablewriter~=1.2->rl_zoo3==2.6.0) (75.2.0)
# Collecting DataProperty<2,>=1.1.0 (from pytablewriter~=1.2->rl_zoo3==2.6.0)
#   Downloading DataProperty-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=1.2->rl_zoo3==2.6.0)
#   Downloading mbstrdecoder-1.1.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter~=1.2->rl_zoo3==2.6.0)
#   Downloading pathvalidate-3.2.3-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter~=1.2->rl_zoo3==2.6.0)
#   Downloading tabledata-1.3.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=1.2->rl_zoo3==2.6.0)
#   Downloading tcolorpy-0.1.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.6.0)
#   Downloading typepy-1.3.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting stable_baselines3<3.0,>=2.6.0 (from sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0)
#   Downloading stable_baselines3-2.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->rl_zoo3==2.6.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->rl_zoo3==2.6.0) (2.18.0)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.6.0) (1.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (2.32.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.6.0) (0.1.2)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.11/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3==2.6.0) (5.2.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.0->rl_zoo3==2.6.0) (3.1.1)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (2.6.0+cu124)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (3.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.6.0) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.11/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.6.0) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.6.0) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (3.2.3)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3_contrib<3.0,>=2.6.0->rl_zoo3==2.6.0) (3.0.2)
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Downloading optuna-4.2.1-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 17.1 MB/s eta 0:00:00
# Downloading pytablewriter-1.2.1-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 8.3 MB/s eta 0:00:00
# Downloading sb3_contrib-2.6.0-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.8/92.8 kB 9.3 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 21.2 MB/s eta 0:00:00
# Downloading DataProperty-1.1.0-py3-none-any.whl (27 kB)
# Downloading mbstrdecoder-1.1.4-py3-none-any.whl (7.9 kB)
# Downloading pathvalidate-3.2.3-py3-none-any.whl (24 kB)
# Downloading stable_baselines3-2.6.0-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 10.8 MB/s eta 0:00:00
# Downloading tabledata-1.3.4-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.7-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.4-py3-none-any.whl (31 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.8 MB/s eta 0:00:00
# Building wheels for collected packages: rl_zoo3
#   Building wheel for rl_zoo3 (pyproject.toml) ... done
#   Created wheel for rl_zoo3: filename=rl_zoo3-2.6.0-py3-none-any.whl size=77819 sha256=6a949ddc758251bd8a0b505425039f89358df131a2b92285d7ec8a96bdfd70b9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pb22uin0/wheels/79/a7/a1/afc7c6c739a99c02b2cba585d219d453a80ab2bff20fb6526f
# Successfully built rl_zoo3
# Installing collected packages: tcolorpy, pathvalidate, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mbstrdecoder, colorlog, typepy, shimmy, nvidia-cusparse-cu12, nvidia-cudnn-cu12, alembic, optuna, nvidia-cusolver-cu12, huggingface_sb3, DataProperty, tabledata, stable_baselines3, sb3_contrib, pytablewriter, rl_zoo3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed DataProperty-1.1.0 alembic-1.15.2 colorlog-6.9.0 huggingface_sb3-3.0 mbstrdecoder-1.1.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 optuna-4.2.1 pathvalidate-3.2.3 pytablewriter-1.2.1 rl_zoo3-2.6.0 sb3_contrib-2.6.0 shimmy-2.0.0 stable_baselines3-2.6.0 tabledata-1.3.4 tcolorpy-0.1.7 typepy-1.3.4

# %% [markdown]
# - `swig`: Install SWIG (Simplified Wrapper and Interface Generator), which is a tool used to connect programs written in C or C++ with various high-level programming languages.
#
# - `cmake`: Install CMake, a tool used for managing the build process of software projects.
#
# - `ffmpeg`: Install FFmpeg, a multimedia framework used for video, audio, and other multimedia files conversion, streaming, and processing.

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 29 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 2s (471 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 126210 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# ## 2. Virtual Display

# %%
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package python-opengl
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common
# The following NEW packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common xvfb
# 0 upgraded, 9 newly installed, 0 to remove and 29 not upgraded.
# Need to get 7,814 kB of archives.
# After this operation, 12.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.13 [29.1 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.13 [863 kB]
# Fetched 7,814 kB in 3s (2,864 kB/s)
# Selecting previously unselected package libfontenc1:amd64.
# (Reading database ... 126963 files and directories currently installed.)
# Preparing to unpack .../0-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../1-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../2-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../3-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../4-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../5-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../6-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../7-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.13_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.13) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../8-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.13_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.13) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.13) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.13) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0

# %% [markdown]
# ## 3. Train Deep O-Learning to play space invaders

# %% [markdown]
# # dqn.yml configuration example
# - policy: 'MlpPolicy'
# - buffer_size: 1000000
# - learning_starts: 10000
# - batch_size: 32
# - learning_rate: 0.00025
# - target_update_interval: 1000
# - gamma: 0.99
# - train_freq: 4
# - gradient_steps: 1
# - n_steps: 1
# - exploration_fraction: 0.1
# - exploration_final_eps: 0.02

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml
# Out:
# Streaming output truncated to the last 5000 lines.
# |    n_updates        | 228581   |
# ----------------------------------
# Eval num_timesteps=925000, episode_reward=324.00 +/- 128.66
# Episode length: 2821.00 +/- 618.91
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.82e+03 |
# |    mean_reward      | 324      |
# | rollout/            |          |
# |    exploration_rate | 0.0843   |
# | time/               |          |
# |    total_timesteps  | 925000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 228749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 392      |
# |    exploration_rate | 0.0839   |
# | time/               |          |
# |    episodes         | 4660     |
# |    fps              | 287      |
# |    time_elapsed     | 3219     |
# |    total_timesteps  | 925364   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0515   |
# |    n_updates        | 228840   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 388      |
# |    exploration_rate | 0.0829   |
# | time/               |          |
# |    episodes         | 4664     |
# |    fps              | 287      |
# |    time_elapsed     | 3223     |
# |    total_timesteps  | 926401   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.035    |
# |    n_updates        | 229100   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 387      |
# |    exploration_rate | 0.0814   |
# | time/               |          |
# |    episodes         | 4668     |
# |    fps              | 287      |
# |    time_elapsed     | 3228     |
# |    total_timesteps  | 927843   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0247   |
# |    n_updates        | 229460   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.0803   |
# | time/               |          |
# |    episodes         | 4672     |
# |    fps              | 287      |
# |    time_elapsed     | 3232     |
# |    total_timesteps  | 928977   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0176   |
# |    n_updates        | 229744   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.0792   |
# | time/               |          |
# |    episodes         | 4676     |
# |    fps              | 287      |
# |    time_elapsed     | 3236     |
# |    total_timesteps  | 930106   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0565   |
# |    n_updates        | 230026   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 387      |
# |    exploration_rate | 0.078    |
# | time/               |          |
# |    episodes         | 4680     |
# |    fps              | 287      |
# |    time_elapsed     | 3240     |
# |    total_timesteps  | 931281   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.171    |
# |    n_updates        | 230320   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.0773   |
# | time/               |          |
# |    episodes         | 4684     |
# |    fps              | 287      |
# |    time_elapsed     | 3243     |
# |    total_timesteps  | 932000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00917  |
# |    n_updates        | 230499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 383      |
# |    exploration_rate | 0.076    |
# | time/               |          |
# |    episodes         | 4688     |
# |    fps              | 287      |
# |    time_elapsed     | 3248     |
# |    total_timesteps  | 933294   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0224   |
# |    n_updates        | 230823   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.0746   |
# | time/               |          |
# |    episodes         | 4692     |
# |    fps              | 287      |
# |    time_elapsed     | 3253     |
# |    total_timesteps  | 934727   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.13     |
# |    n_updates        | 231181   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 387      |
# |    exploration_rate | 0.0739   |
# | time/               |          |
# |    episodes         | 4696     |
# |    fps              | 287      |
# |    time_elapsed     | 3255     |
# |    total_timesteps  | 935461   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0219   |
# |    n_updates        | 231365   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 389      |
# |    exploration_rate | 0.0729   |
# | time/               |          |
# |    episodes         | 4700     |
# |    fps              | 287      |
# |    time_elapsed     | 3259     |
# |    total_timesteps  | 936454   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 231613   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 389      |
# |    exploration_rate | 0.0723   |
# | time/               |          |
# |    episodes         | 4704     |
# |    fps              | 287      |
# |    time_elapsed     | 3262     |
# |    total_timesteps  | 937067   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 231766   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 388      |
# |    exploration_rate | 0.0708   |
# | time/               |          |
# |    episodes         | 4708     |
# |    fps              | 287      |
# |    time_elapsed     | 3267     |
# |    total_timesteps  | 938590   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0174   |
# |    n_updates        | 232147   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 393      |
# |    exploration_rate | 0.0695   |
# | time/               |          |
# |    episodes         | 4712     |
# |    fps              | 287      |
# |    time_elapsed     | 3272     |
# |    total_timesteps  | 939885   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0322   |
# |    n_updates        | 232471   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 391      |
# |    exploration_rate | 0.0689   |
# | time/               |          |
# |    episodes         | 4716     |
# |    fps              | 287      |
# |    time_elapsed     | 3274     |
# |    total_timesteps  | 940492   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 232622   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 389      |
# |    exploration_rate | 0.0677   |
# | time/               |          |
# |    episodes         | 4720     |
# |    fps              | 287      |
# |    time_elapsed     | 3278     |
# |    total_timesteps  | 941697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0273   |
# |    n_updates        | 232924   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.0662   |
# | time/               |          |
# |    episodes         | 4724     |
# |    fps              | 287      |
# |    time_elapsed     | 3284     |
# |    total_timesteps  | 943238   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 233309   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 390      |
# |    exploration_rate | 0.0656   |
# | time/               |          |
# |    episodes         | 4728     |
# |    fps              | 287      |
# |    time_elapsed     | 3286     |
# |    total_timesteps  | 943877   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0228   |
# |    n_updates        | 233469   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 393      |
# |    exploration_rate | 0.0644   |
# | time/               |          |
# |    episodes         | 4732     |
# |    fps              | 287      |
# |    time_elapsed     | 3291     |
# |    total_timesteps  | 945099   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0126   |
# |    n_updates        | 233774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 395      |
# |    exploration_rate | 0.0632   |
# | time/               |          |
# |    episodes         | 4736     |
# |    fps              | 287      |
# |    time_elapsed     | 3295     |
# |    total_timesteps  | 946268   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0317   |
# |    n_updates        | 234066   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 393      |
# |    exploration_rate | 0.0624   |
# | time/               |          |
# |    episodes         | 4740     |
# |    fps              | 287      |
# |    time_elapsed     | 3298     |
# |    total_timesteps  | 947078   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 234269   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 394      |
# |    exploration_rate | 0.0612   |
# | time/               |          |
# |    episodes         | 4744     |
# |    fps              | 287      |
# |    time_elapsed     | 3302     |
# |    total_timesteps  | 948321   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 234580   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 397      |
# |    exploration_rate | 0.0601   |
# | time/               |          |
# |    episodes         | 4748     |
# |    fps              | 287      |
# |    time_elapsed     | 3306     |
# |    total_timesteps  | 949395   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0126   |
# |    n_updates        | 234848   |
# ----------------------------------
# Eval num_timesteps=950000, episode_reward=492.00 +/- 220.88
# Episode length: 3373.40 +/- 930.91
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.37e+03 |
# |    mean_reward      | 492      |
# | rollout/            |          |
# |    exploration_rate | 0.0595   |
# | time/               |          |
# |    total_timesteps  | 950000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0271   |
# |    n_updates        | 234999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.0592   |
# | time/               |          |
# |    episodes         | 4752     |
# |    fps              | 286      |
# |    time_elapsed     | 3319     |
# |    total_timesteps  | 950339   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00986  |
# |    n_updates        | 235084   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 402      |
# |    exploration_rate | 0.0577   |
# | time/               |          |
# |    episodes         | 4756     |
# |    fps              | 286      |
# |    time_elapsed     | 3325     |
# |    total_timesteps  | 951864   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00628  |
# |    n_updates        | 235465   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 407      |
# |    exploration_rate | 0.0561   |
# | time/               |          |
# |    episodes         | 4760     |
# |    fps              | 286      |
# |    time_elapsed     | 3330     |
# |    total_timesteps  | 953467   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00834  |
# |    n_updates        | 235866   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.0552   |
# | time/               |          |
# |    episodes         | 4764     |
# |    fps              | 286      |
# |    time_elapsed     | 3334     |
# |    total_timesteps  | 954353   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0207   |
# |    n_updates        | 236088   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 406      |
# |    exploration_rate | 0.0541   |
# | time/               |          |
# |    episodes         | 4768     |
# |    fps              | 286      |
# |    time_elapsed     | 3338     |
# |    total_timesteps  | 955494   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0201   |
# |    n_updates        | 236373   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 404      |
# |    exploration_rate | 0.053    |
# | time/               |          |
# |    episodes         | 4772     |
# |    fps              | 286      |
# |    time_elapsed     | 3342     |
# |    total_timesteps  | 956599   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0226   |
# |    n_updates        | 236649   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 405      |
# |    exploration_rate | 0.0518   |
# | time/               |          |
# |    episodes         | 4776     |
# |    fps              | 286      |
# |    time_elapsed     | 3346     |
# |    total_timesteps  | 957819   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00872  |
# |    n_updates        | 236954   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 402      |
# |    exploration_rate | 0.0506   |
# | time/               |          |
# |    episodes         | 4780     |
# |    fps              | 286      |
# |    time_elapsed     | 3350     |
# |    total_timesteps  | 959009   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0254   |
# |    n_updates        | 237252   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 406      |
# |    exploration_rate | 0.0494   |
# | time/               |          |
# |    episodes         | 4784     |
# |    fps              | 286      |
# |    time_elapsed     | 3354     |
# |    total_timesteps  | 960165   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0371   |
# |    n_updates        | 237541   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.048    |
# | time/               |          |
# |    episodes         | 4788     |
# |    fps              | 286      |
# |    time_elapsed     | 3360     |
# |    total_timesteps  | 961600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00809  |
# |    n_updates        | 237899   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.24e+03 |
# |    ep_rew_mean      | 412      |
# |    exploration_rate | 0.047    |
# | time/               |          |
# |    episodes         | 4792     |
# |    fps              | 286      |
# |    time_elapsed     | 3364     |
# |    total_timesteps  | 962577   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0345   |
# |    n_updates        | 238144   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.0463   |
# | time/               |          |
# |    episodes         | 4796     |
# |    fps              | 286      |
# |    time_elapsed     | 3366     |
# |    total_timesteps  | 963316   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00458  |
# |    n_updates        | 238328   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.24e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.0451   |
# | time/               |          |
# |    episodes         | 4800     |
# |    fps              | 286      |
# |    time_elapsed     | 3372     |
# |    total_timesteps  | 964567   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0224   |
# |    n_updates        | 238641   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 409      |
# |    exploration_rate | 0.0443   |
# | time/               |          |
# |    episodes         | 4804     |
# |    fps              | 286      |
# |    time_elapsed     | 3375     |
# |    total_timesteps  | 965316   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 238828   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 404      |
# |    exploration_rate | 0.0438   |
# | time/               |          |
# |    episodes         | 4808     |
# |    fps              | 286      |
# |    time_elapsed     | 3377     |
# |    total_timesteps  | 965859   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 238964   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 406      |
# |    exploration_rate | 0.0428   |
# | time/               |          |
# |    episodes         | 4812     |
# |    fps              | 285      |
# |    time_elapsed     | 3381     |
# |    total_timesteps  | 966898   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0262   |
# |    n_updates        | 239224   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.0417   |
# | time/               |          |
# |    episodes         | 4816     |
# |    fps              | 285      |
# |    time_elapsed     | 3385     |
# |    total_timesteps  | 968009   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0111   |
# |    n_updates        | 239502   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 409      |
# |    exploration_rate | 0.0401   |
# | time/               |          |
# |    episodes         | 4820     |
# |    fps              | 285      |
# |    time_elapsed     | 3391     |
# |    total_timesteps  | 969575   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 239893   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 409      |
# |    exploration_rate | 0.0394   |
# | time/               |          |
# |    episodes         | 4824     |
# |    fps              | 285      |
# |    time_elapsed     | 3394     |
# |    total_timesteps  | 970279   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.135    |
# |    n_updates        | 240069   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.0382   |
# | time/               |          |
# |    episodes         | 4828     |
# |    fps              | 285      |
# |    time_elapsed     | 3398     |
# |    total_timesteps  | 971509   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0092   |
# |    n_updates        | 240377   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 409      |
# |    exploration_rate | 0.0371   |
# | time/               |          |
# |    episodes         | 4832     |
# |    fps              | 285      |
# |    time_elapsed     | 3402     |
# |    total_timesteps  | 972639   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00965  |
# |    n_updates        | 240659   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.24e+03 |
# |    ep_rew_mean      | 415      |
# |    exploration_rate | 0.036    |
# | time/               |          |
# |    episodes         | 4836     |
# |    fps              | 285      |
# |    time_elapsed     | 3407     |
# |    total_timesteps  | 973703   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 240925   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 415      |
# |    exploration_rate | 0.0352   |
# | time/               |          |
# |    episodes         | 4840     |
# |    fps              | 285      |
# |    time_elapsed     | 3410     |
# |    total_timesteps  | 974591   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0548   |
# |    n_updates        | 241147   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=601.00 +/- 72.14
# Episode length: 4047.60 +/- 42.68
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.05e+03 |
# |    mean_reward      | 601      |
# | rollout/            |          |
# |    exploration_rate | 0.0348   |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 241249   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 411      |
# |    exploration_rate | 0.0343   |
# | time/               |          |
# |    episodes         | 4844     |
# |    fps              | 284      |
# |    time_elapsed     | 3424     |
# |    total_timesteps  | 975466   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0096   |
# |    n_updates        | 241366   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 405      |
# |    exploration_rate | 0.0337   |
# | time/               |          |
# |    episodes         | 4848     |
# |    fps              | 284      |
# |    time_elapsed     | 3427     |
# |    total_timesteps  | 976101   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0138   |
# |    n_updates        | 241525   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 406      |
# |    exploration_rate | 0.0327   |
# | time/               |          |
# |    episodes         | 4852     |
# |    fps              | 284      |
# |    time_elapsed     | 3431     |
# |    total_timesteps  | 977082   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 241770   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 407      |
# |    exploration_rate | 0.0315   |
# | time/               |          |
# |    episodes         | 4856     |
# |    fps              | 284      |
# |    time_elapsed     | 3435     |
# |    total_timesteps  | 978274   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 242068   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 406      |
# |    exploration_rate | 0.0305   |
# | time/               |          |
# |    episodes         | 4860     |
# |    fps              | 284      |
# |    time_elapsed     | 3438     |
# |    total_timesteps  | 979290   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00716  |
# |    n_updates        | 242322   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.0286   |
# | time/               |          |
# |    episodes         | 4864     |
# |    fps              | 284      |
# |    time_elapsed     | 3446     |
# |    total_timesteps  | 981234   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0116   |
# |    n_updates        | 242808   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 413      |
# |    exploration_rate | 0.0275   |
# | time/               |          |
# |    episodes         | 4868     |
# |    fps              | 284      |
# |    time_elapsed     | 3449     |
# |    total_timesteps  | 982277   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0349   |
# |    n_updates        | 243069   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.0264   |
# | time/               |          |
# |    episodes         | 4872     |
# |    fps              | 284      |
# |    time_elapsed     | 3454     |
# |    total_timesteps  | 983484   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0208   |
# |    n_updates        | 243370   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 417      |
# |    exploration_rate | 0.0257   |
# | time/               |          |
# |    episodes         | 4876     |
# |    fps              | 284      |
# |    time_elapsed     | 3456     |
# |    total_timesteps  | 984105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0164   |
# |    n_updates        | 243526   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.0242   |
# | time/               |          |
# |    episodes         | 4880     |
# |    fps              | 284      |
# |    time_elapsed     | 3461     |
# |    total_timesteps  | 985621   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0203   |
# |    n_updates        | 243905   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.24e+03 |
# |    ep_rew_mean      | 417      |
# |    exploration_rate | 0.0235   |
# | time/               |          |
# |    episodes         | 4884     |
# |    fps              | 284      |
# |    time_elapsed     | 3464     |
# |    total_timesteps  | 986341   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.026    |
# |    n_updates        | 244085   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 417      |
# |    exploration_rate | 0.0223   |
# | time/               |          |
# |    episodes         | 4888     |
# |    fps              | 284      |
# |    time_elapsed     | 3469     |
# |    total_timesteps  | 987605   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0426   |
# |    n_updates        | 244401   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 414      |
# |    exploration_rate | 0.0216   |
# | time/               |          |
# |    episodes         | 4892     |
# |    fps              | 284      |
# |    time_elapsed     | 3471     |
# |    total_timesteps  | 988247   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0928   |
# |    n_updates        | 244561   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 414      |
# |    exploration_rate | 0.0207   |
# | time/               |          |
# |    episodes         | 4896     |
# |    fps              | 284      |
# |    time_elapsed     | 3474     |
# |    total_timesteps  | 989142   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 244785   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 412      |
# |    exploration_rate | 0.0197   |
# | time/               |          |
# |    episodes         | 4900     |
# |    fps              | 284      |
# |    time_elapsed     | 3478     |
# |    total_timesteps  | 990179   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0289   |
# |    n_updates        | 245044   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 411      |
# |    exploration_rate | 0.0187   |
# | time/               |          |
# |    episodes         | 4904     |
# |    fps              | 284      |
# |    time_elapsed     | 3482     |
# |    total_timesteps  | 991235   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0254   |
# |    n_updates        | 245308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 413      |
# |    exploration_rate | 0.0172   |
# | time/               |          |
# |    episodes         | 4908     |
# |    fps              | 284      |
# |    time_elapsed     | 3487     |
# |    total_timesteps  | 992731   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 245682   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 415      |
# |    exploration_rate | 0.0167   |
# | time/               |          |
# |    episodes         | 4912     |
# |    fps              | 284      |
# |    time_elapsed     | 3489     |
# |    total_timesteps  | 993271   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00705  |
# |    n_updates        | 245817   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.0156   |
# | time/               |          |
# |    episodes         | 4916     |
# |    fps              | 284      |
# |    time_elapsed     | 3494     |
# |    total_timesteps  | 994349   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0242   |
# |    n_updates        | 246087   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.0143   |
# | time/               |          |
# |    episodes         | 4920     |
# |    fps              | 284      |
# |    time_elapsed     | 3498     |
# |    total_timesteps  | 995612   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0512   |
# |    n_updates        | 246402   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.0132   |
# | time/               |          |
# |    episodes         | 4924     |
# |    fps              | 284      |
# |    time_elapsed     | 3502     |
# |    total_timesteps  | 996719   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0134   |
# |    n_updates        | 246679   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 415      |
# |    exploration_rate | 0.0117   |
# | time/               |          |
# |    episodes         | 4928     |
# |    fps              | 284      |
# |    time_elapsed     | 3508     |
# |    total_timesteps  | 998279   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 247069   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.0109   |
# | time/               |          |
# |    episodes         | 4932     |
# |    fps              | 284      |
# |    time_elapsed     | 3511     |
# |    total_timesteps  | 999099   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00758  |
# |    n_updates        | 247274   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=439.00 +/- 70.24
# Episode length: 3395.20 +/- 590.41
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.4e+03  |
# |    mean_reward      | 439      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 247499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 422      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4936     |
# |    fps              | 283      |
# |    time_elapsed     | 3524     |
# |    total_timesteps  | 1000192  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 247547   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 422      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4940     |
# |    fps              | 283      |
# |    time_elapsed     | 3528     |
# |    total_timesteps  | 1001156  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0276   |
# |    n_updates        | 247788   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 422      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4944     |
# |    fps              | 283      |
# |    time_elapsed     | 3533     |
# |    total_timesteps  | 1002476  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00813  |
# |    n_updates        | 248118   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 425      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4948     |
# |    fps              | 283      |
# |    time_elapsed     | 3538     |
# |    total_timesteps  | 1003834  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 248458   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 423      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4952     |
# |    fps              | 283      |
# |    time_elapsed     | 3540     |
# |    total_timesteps  | 1004508  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.034    |
# |    n_updates        | 248626   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 427      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4956     |
# |    fps              | 283      |
# |    time_elapsed     | 3544     |
# |    total_timesteps  | 1005395  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0164   |
# |    n_updates        | 248848   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 431      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4960     |
# |    fps              | 283      |
# |    time_elapsed     | 3548     |
# |    total_timesteps  | 1006820  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00893  |
# |    n_updates        | 249204   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4964     |
# |    fps              | 283      |
# |    time_elapsed     | 3554     |
# |    total_timesteps  | 1008306  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0085   |
# |    n_updates        | 249576   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4968     |
# |    fps              | 283      |
# |    time_elapsed     | 3558     |
# |    total_timesteps  | 1009446  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 249861   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 437      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4972     |
# |    fps              | 283      |
# |    time_elapsed     | 3561     |
# |    total_timesteps  | 1010209  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 250052   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 438      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4976     |
# |    fps              | 283      |
# |    time_elapsed     | 3567     |
# |    total_timesteps  | 1011779  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0341   |
# |    n_updates        | 250444   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4980     |
# |    fps              | 283      |
# |    time_elapsed     | 3570     |
# |    total_timesteps  | 1012677  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0129   |
# |    n_updates        | 250669   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 433      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4984     |
# |    fps              | 283      |
# |    time_elapsed     | 3574     |
# |    total_timesteps  | 1013744  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 250935   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.2e+03  |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4988     |
# |    fps              | 283      |
# |    time_elapsed     | 3580     |
# |    total_timesteps  | 1015207  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 251301   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 433      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4992     |
# |    fps              | 283      |
# |    time_elapsed     | 3583     |
# |    total_timesteps  | 1016036  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0209   |
# |    n_updates        | 251508   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 431      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4996     |
# |    fps              | 283      |
# |    time_elapsed     | 3586     |
# |    total_timesteps  | 1016945  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0138   |
# |    n_updates        | 251736   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 430      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5000     |
# |    fps              | 283      |
# |    time_elapsed     | 3591     |
# |    total_timesteps  | 1018271  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.012    |
# |    n_updates        | 252067   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 433      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5004     |
# |    fps              | 283      |
# |    time_elapsed     | 3595     |
# |    total_timesteps  | 1019394  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0256   |
# |    n_updates        | 252348   |
# ...
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0126   |
# |    n_updates        | 314912   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.59e+03 |
# |    ep_rew_mean      | 530      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5816     |
# |    fps              | 274      |
# |    time_elapsed     | 4623     |
# |    total_timesteps  | 1270845  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0103   |
# |    n_updates        | 315211   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | 531      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5820     |
# |    fps              | 274      |
# |    time_elapsed     | 4629     |
# |    total_timesteps  | 1272406  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.136    |
# |    n_updates        | 315601   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.59e+03 |
# |    ep_rew_mean      | 530      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5824     |
# |    fps              | 274      |
# |    time_elapsed     | 4633     |
# |    total_timesteps  | 1273577  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 315894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | 532      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5828     |
# |    fps              | 274      |
# |    time_elapsed     | 4639     |
# |    total_timesteps  | 1274943  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0399   |
# |    n_updates        | 316235   |
# ----------------------------------
# Eval num_timesteps=1275000, episode_reward=575.00 +/- 83.67
# Episode length: 3743.40 +/- 618.39
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.74e+03 |
# |    mean_reward      | 575      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1275000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 316249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | 532      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5832     |
# |    fps              | 274      |
# |    time_elapsed     | 4656     |
# |    total_timesteps  | 1276898  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00924  |
# |    n_updates        | 316724   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | 535      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5836     |
# |    fps              | 274      |
# |    time_elapsed     | 4662     |
# |    total_timesteps  | 1278432  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0333   |
# |    n_updates        | 317107   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | 532      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5840     |
# |    fps              | 274      |
# |    time_elapsed     | 4668     |
# |    total_timesteps  | 1280296  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0265   |
# |    n_updates        | 317573   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | 529      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5844     |
# |    fps              | 274      |
# |    time_elapsed     | 4672     |
# |    total_timesteps  | 1281330  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 317832   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | 531      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5848     |
# |    fps              | 274      |
# |    time_elapsed     | 4677     |
# |    total_timesteps  | 1282714  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.118    |
# |    n_updates        | 318178   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | 529      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5852     |
# |    fps              | 274      |
# |    time_elapsed     | 4680     |
# |    total_timesteps  | 1283522  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0646   |
# |    n_updates        | 318380   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.59e+03 |
# |    ep_rew_mean      | 527      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5856     |
# |    fps              | 274      |
# |    time_elapsed     | 4684     |
# |    total_timesteps  | 1284643  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0983   |
# |    n_updates        | 318660   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | 525      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5860     |
# |    fps              | 274      |
# |    time_elapsed     | 4690     |
# |    total_timesteps  | 1286054  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0249   |
# |    n_updates        | 319013   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.59e+03 |
# |    ep_rew_mean      | 525      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5864     |
# |    fps              | 274      |
# |    time_elapsed     | 4693     |
# |    total_timesteps  | 1286907  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0291   |
# |    n_updates        | 319226   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.56e+03 |
# |    ep_rew_mean      | 524      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5868     |
# |    fps              | 274      |
# |    time_elapsed     | 4695     |
# |    total_timesteps  | 1287463  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.101    |
# |    n_updates        | 319365   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.55e+03 |
# |    ep_rew_mean      | 522      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5872     |
# |    fps              | 274      |
# |    time_elapsed     | 4699     |
# |    total_timesteps  | 1288467  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0191   |
# |    n_updates        | 319616   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.56e+03 |
# |    ep_rew_mean      | 526      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5876     |
# |    fps              | 274      |
# |    time_elapsed     | 4703     |
# |    total_timesteps  | 1289665  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00703  |
# |    n_updates        | 319916   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.58e+03 |
# |    ep_rew_mean      | 530      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5880     |
# |    fps              | 274      |
# |    time_elapsed     | 4708     |
# |    total_timesteps  | 1290941  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.017    |
# |    n_updates        | 320235   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.58e+03 |
# |    ep_rew_mean      | 529      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5884     |
# |    fps              | 274      |
# |    time_elapsed     | 4712     |
# |    total_timesteps  | 1292185  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.13     |
# |    n_updates        | 320546   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.59e+03 |
# |    ep_rew_mean      | 529      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5888     |
# |    fps              | 274      |
# |    time_elapsed     | 4716     |
# |    total_timesteps  | 1293328  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0285   |
# |    n_updates        | 320831   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.56e+03 |
# |    ep_rew_mean      | 528      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5892     |
# |    fps              | 274      |
# |    time_elapsed     | 4719     |
# |    total_timesteps  | 1293977  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00676  |
# |    n_updates        | 320994   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.57e+03 |
# |    ep_rew_mean      | 529      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5896     |
# |    fps              | 274      |
# |    time_elapsed     | 4725     |
# |    total_timesteps  | 1295732  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0365   |
# |    n_updates        | 321432   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.58e+03 |
# |    ep_rew_mean      | 531      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5900     |
# |    fps              | 274      |
# |    time_elapsed     | 4730     |
# |    total_timesteps  | 1296958  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 321739   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.59e+03 |
# |    ep_rew_mean      | 535      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5904     |
# |    fps              | 274      |
# |    time_elapsed     | 4735     |
# |    total_timesteps  | 1298281  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 322070   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.59e+03 |
# |    ep_rew_mean      | 537      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5908     |
# |    fps              | 274      |
# |    time_elapsed     | 4738     |
# |    total_timesteps  | 1299305  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 322326   |
# ----------------------------------
# Eval num_timesteps=1300000, episode_reward=586.00 +/- 114.43
# Episode length: 3851.80 +/- 781.80
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.85e+03 |
# |    mean_reward      | 586      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1300000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.151    |
# |    n_updates        | 322499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | 538      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5912     |
# |    fps              | 273      |
# |    time_elapsed     | 4755     |
# |    total_timesteps  | 1300997  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00606  |
# |    n_updates        | 322749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | 539      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5916     |
# |    fps              | 273      |
# |    time_elapsed     | 4759     |
# |    total_timesteps  | 1302152  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0307   |
# |    n_updates        | 323037   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.58e+03 |
# |    ep_rew_mean      | 536      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5920     |
# |    fps              | 273      |
# |    time_elapsed     | 4762     |
# |    total_timesteps  | 1302902  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0142   |
# |    n_updates        | 323225   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.57e+03 |
# |    ep_rew_mean      | 533      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 5924     |
# |    fps              | 273      |
# |    time_elapsed     | 4766     |
# |    total_timesteps  | 1303989  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 323497   |
# ----------------------------------

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# ## Saving the Model

# %%
from huggingface_hub import notebook_login
notebook_login()
# !git config --global credential.helper store

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga Adiii143  -f logs/
